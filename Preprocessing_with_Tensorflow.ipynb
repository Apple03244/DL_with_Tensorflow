# %%
# %pwd
# Out:
# '/content'

# %%
import google.colab as colab

# %%
colab.drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name "Apple03244"
# !git config --global user.email "apple03244@gmail.com"

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd

# %%
# !git add /content/drive/MyDrive/Colab Notebooks/DL_with_Tensorflow/TFR_protobuf.proto
