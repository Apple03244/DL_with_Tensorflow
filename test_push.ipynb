# %%
import google.colab as colab

# %%
colab.drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/DL_with_Tensorflow
# Out:
# /content/drive/MyDrive/Colab Notebooks/DL_with_Tensorflow

# %%
p
